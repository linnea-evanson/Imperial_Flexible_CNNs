# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# ================================================= Flexible Layer ================================================================================

    
class FlexiLayer(nn.Module): # class FlexiLayer(nn.Conv2d):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1,
                 padding=0):
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.stride = stride
        self.padding = padding
        super(FlexiLayer, self).__init__()
        
        self.t_1 = nn.Conv2d(self.in_channels, self.out_channels, self.kernel_size, self.stride, self.padding)
        self.t_2 = nn.MaxPool2d(self.kernel_size, self.stride, self.padding) # get max result with the same kernel size
        self.m = nn.Sigmoid()
        
        #self.thresh_mean = []
        
    def forward(self, t):
        
        self.mask = torch.empty(1, self.out_channels, 30, 30).random_(2)        
        
        t_2_2 = self.mask.cuda()*self.t_2(t) # MAX if true
        t_1_1 = (1-self.mask.cuda())*self.t_1(t) # CONV if false
        t = torch.add(t_2_2, t_1_1)
        
        return t

    # ================================================= VGG-16 Network ================================================================================
class VGG16(nn.Module):
    def __init__(self):
        super(VGG16,self).__init__()

        self.block1 = nn.Sequential(
                      nn.Conv2d(in_channels = 3,out_channels = 64,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(64),
                      nn.ReLU(),
                      FlexiLayer(in_channels = 64,out_channels = 64,kernel_size = 3, padding =0),
                      nn.BatchNorm2d(64),
                      nn.ReLU(),
                      #nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.3))

        self.block2 = nn.Sequential(
                      nn.Conv2d(in_channels = 64,out_channels = 128,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(128),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 128,out_channels = 128,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(128),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.4))

        self.block3 = nn.Sequential(
                      nn.Conv2d(in_channels = 128,out_channels = 256,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(256),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(256),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(256),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.4))

        self.block4 = nn.Sequential(
                      nn.Conv2d(in_channels = 256,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2) ,
                      nn.Dropout2d(0.4))

        self.block5 = nn.Sequential(
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.5) )

        self.fc =     nn.Sequential(
                      nn.Linear(512,100),
                      nn.Dropout(0.5),
                      nn.BatchNorm1d(100),
                      nn.ReLU(),
                      nn.Dropout(0.5),
                      nn.Linear(100,10), )

    def forward(self,x):
        out = self.block1(x)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = out.view(out.size(0),-1)
        out = self.fc(out)

        return out

# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np


# =================================================== Prepare the dataset ===============================================================================

mean_cifar10 = [0.485, 0.456, 0.406]  # Mean and Std value hase been taken from a github implmentation online.
std_cifar10 = [0.229, 0.224, 0.225]
batch_size = 100
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

trainset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=True, download= True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') # 10 Classes of the cifar-10

# ========================================== Visualising the dataset ==========================================================================
std= torch.FloatTensor(std_cifar10)
mean = torch.FloatTensor(mean_cifar10)
mean = mean[:,None,None]
std = std[:,None,None]
def imshow(img):
    print(img.size())
    img = img*std + mean     # unnormalize
    
    npimg = img.numpy()
    
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
#  ship truck   car truck

# %%
# =============================================================== Model initialisation, Loss function and Optimizer =====================================
model = VGG16()
if torch.cuda.is_available():
    model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum = 0.9,weight_decay = 0.006)
schedule = torch.optim.lr_scheduler.StepLR(optimizer,step_size=20,gamma = 0.7)

total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} trainable parameters.')
# Out:
# 14,775,646 total parameters.
# 14,775,646 trainable parameters.

# %%
# ======================== Function to get the test accuracy ===============================================================================
def test():
    correct = 0
    total = 0
    model.train(False)
    with torch.no_grad():
        for i,(images,labels)in enumerate(testloader):
            if torch.cuda.is_available():
                images = images.cuda()
                labels = labels.cuda()
            outputs = model(Variable(images))
            labels = Variable(labels)
            _,predicted = outputs.max(1)
            total += labels.size(0)
            correct += (predicted.eq(labels)).sum().item()
    print('Test accuracy: %d %%' % (
  100 * correct / total))
    return 100*(correct/total)

#======================================================= Training =========================================================================
num_epochs = 152  # Train for 150 epochs
start_epoch = 0

total_step = len(trainloader)
train_loss = []  # Store the train_loss per epoch
test_accuracy = [] # Store the test_accuracy per epoch
for epoch in range(start_epoch,num_epochs+1):
    model.train(True)
    epoch_loss  = 0
    i_count = 0
    acc_total = 0
    for i,(images,labels) in enumerate(trainloader):
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()
        labels = Variable(labels)
        optimizer.zero_grad()
        outputs = model(Variable(images))
        loss = criterion(outputs,labels)
        epoch_loss += loss.item()
        loss.backward()
        optimizer.step()
        _,predicted = outputs.max(1)
        denom = labels.size(0)
        correct = predicted.eq(labels).sum().item()
        acc = 100*(correct/denom)
        acc_total += acc
        i_count = i_count + 1
    
    #if(i%20 == 0):  # Print the loss per 20 iterations
      #print("Epoch: ",epoch," ","Iteration: ",i," loss: ",loss.item()," Train_iter Accuracy: ",acc)
    schedule.step()
    train_loss.append(epoch_loss)
    print("Epoch: ",epoch," ","Loss: ",epoch_loss," ","Train Accuracy :",acc_total/i_count) # Print train accuracy per epoch
    print('\n')
    test_acc = test()      # Print the test accuracy per epoch
    test_accuracy.append(test_acc)
  
    state = {
        'model': model.state_dict(),
        'acc' : test_acc,
        'optim':optimizer.state_dict(),
        'epoch' : epoch
    }
    path = './models/VGG16-FLEX-random_thresh_nnmodule_' + 'model_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
    torch.save(state,path)
# Out:
# Epoch:  0   Loss:  1109.8364819288254   Train Accuracy : 15.904
#
#
# Test accuracy: 14 %
# Epoch:  1   Loss:  982.2992684841156   Train Accuracy : 24.62
#
#
# Test accuracy: 25 %
# Epoch:  2   Loss:  911.2775679826736   Train Accuracy : 30.742
#
#
# Test accuracy: 36 %
# Epoch:  3   Loss:  860.4805438518524   Train Accuracy : 35.026
#
#
# Test accuracy: 41 %
# Epoch:  4   Loss:  824.1812862157822   Train Accuracy : 38.442
#
#
# Test accuracy: 44 %
# Epoch:  5   Loss:  792.6490608453751   Train Accuracy : 41.616
#
#
# Test accuracy: 48 %
# Epoch:  6   Loss:  759.9261300563812   Train Accuracy : 44.82
#
#
# Test accuracy: 51 %
# Epoch:  7   Loss:  732.05158162117   Train Accuracy : 47.794
#
#
# Test accuracy: 55 %
# Epoch:  8   Loss:  698.4861183166504   Train Accuracy : 51.186
#
#
# Test accuracy: 58 %
# Epoch:  9   Loss:  667.4339228868484   Train Accuracy : 53.892
#
#
# Test accuracy: 62 %
# Epoch:  10   Loss:  641.0562154054642   Train Accuracy : 56.77
#
#
# Test accuracy: 63 %
# Epoch:  11   Loss:  617.016555428505   Train Accuracy : 58.994
#
#
# Test accuracy: 66 %
# Epoch:  12   Loss:  592.6908628344536   Train Accuracy : 61.064
#
#
# Test accuracy: 66 %
# Epoch:  13   Loss:  572.5063120722771   Train Accuracy : 62.472
#
#
# Test accuracy: 68 %
# Epoch:  14   Loss:  553.5649089217186   Train Accuracy : 64.248
#
#
# Test accuracy: 69 %
# Epoch:  15   Loss:  531.7574144005775   Train Accuracy : 66.036
#
#
# Test accuracy: 71 %
# Epoch:  16   Loss:  514.3438057303429   Train Accuracy : 67.37
#
#
# Test accuracy: 73 %
# Epoch:  17   Loss:  494.83823388814926   Train Accuracy : 69.04
#
#
# Test accuracy: 75 %
# Epoch:  18   Loss:  480.88019174337387   Train Accuracy : 70.2
#
#
# Test accuracy: 73 %
# Epoch:  19   Loss:  464.09395253658295   Train Accuracy : 71.548
#
#
# Test accuracy: 75 %
# Epoch:  20   Loss:  440.1865013241768   Train Accuracy : 73.274
#
#
# Test accuracy: 78 %
# Epoch:  21   Loss:  422.0331736803055   Train Accuracy : 74.906
#
#
# Test accuracy: 78 %
# Epoch:  22   Loss:  414.25059312582016   Train Accuracy : 75.482
#
#
# Test accuracy: 79 %
# Epoch:  23   Loss:  402.2414942383766   Train Accuracy : 76.302
#
#
# Test accuracy: 79 %
# Epoch:  24   Loss:  396.08953738212585   Train Accuracy : 76.874
#
#
# Test accuracy: 79 %
# Epoch:  25   Loss:  388.0510649085045   Train Accuracy : 77.46
#
#
# Test accuracy: 80 %
# Epoch:  26   Loss:  380.07551968097687   Train Accuracy : 78.004
#
#
# Test accuracy: 81 %
# Epoch:  27   Loss:  370.61384230852127   Train Accuracy : 78.8
#
#
# Test accuracy: 81 %
# Epoch:  28   Loss:  363.88579562306404   Train Accuracy : 79.26
#
#
# Test accuracy: 81 %
# Epoch:  29   Loss:  354.8745581805706   Train Accuracy : 79.794
#
#
# Test accuracy: 82 %
# Epoch:  30   Loss:  347.08766862750053   Train Accuracy : 80.242
#
#
# Test accuracy: 82 %
# Epoch:  31   Loss:  345.51370161771774   Train Accuracy : 80.424
#
#
# Test accuracy: 82 %
# Epoch:  32   Loss:  337.42312398552895   Train Accuracy : 81.004
#
#
# Test accuracy: 82 %
# Epoch:  33   Loss:  330.11658585071564   Train Accuracy : 81.668
#
#
# Test accuracy: 83 %
# Epoch:  34   Loss:  324.31400260329247   Train Accuracy : 81.99
#
#
# Test accuracy: 82 %
# Epoch:  35   Loss:  318.98356130719185   Train Accuracy : 82.544
#
#
# Test accuracy: 84 %
# Epoch:  36   Loss:  313.31054934859276   Train Accuracy : 82.778
#
#
# Test accuracy: 84 %
# Epoch:  37   Loss:  311.29442995786667   Train Accuracy : 83.258
#
#
# Test accuracy: 83 %
# Epoch:  38   Loss:  303.1268962919712   Train Accuracy : 83.558
#
#
# Test accuracy: 84 %
# Epoch:  39   Loss:  299.49106201529503   Train Accuracy : 83.738
#
#
# Test accuracy: 85 %
# Epoch:  40   Loss:  277.5879907011986   Train Accuracy : 85.34
#
#
# Test accuracy: 85 %
# Epoch:  41   Loss:  266.6940263211727   Train Accuracy : 85.94
#
#
# Test accuracy: 85 %
# Epoch:  42   Loss:  264.629083186388   Train Accuracy : 86.138
#
#
# Test accuracy: 86 %
# Epoch:  43   Loss:  258.16631150245667   Train Accuracy : 86.716
#
#
# Test accuracy: 85 %
# Epoch:  44   Loss:  252.9693727195263   Train Accuracy : 86.852
#
#
# Test accuracy: 85 %
# Epoch:  45   Loss:  251.33017602562904   Train Accuracy : 86.956
#
#
# Test accuracy: 86 %
# Epoch:  46   Loss:  249.6766699552536   Train Accuracy : 87.072
#
#
# Test accuracy: 86 %
# Epoch:  47   Loss:  246.9770905971527   Train Accuracy : 87.296
#
#
# Test accuracy: 86 %
# Epoch:  48   Loss:  244.0793389081955   Train Accuracy : 87.574
#
#
# Test accuracy: 86 %
# Epoch:  49   Loss:  239.77158784866333   Train Accuracy : 87.698
#
#
# Test accuracy: 86 %
# Epoch:  50   Loss:  238.2531305551529   Train Accuracy : 87.718
#
#
# Test accuracy: 86 %
# Epoch:  51   Loss:  233.32117947936058   Train Accuracy : 88.024
#
#
# Test accuracy: 86 %
# Epoch:  52   Loss:  231.7079919576645   Train Accuracy : 88.288
#
#
# Test accuracy: 86 %
# Epoch:  53   Loss:  226.20373857021332   Train Accuracy : 88.448
#
#
# Test accuracy: 87 %
# Epoch:  54   Loss:  226.52490310370922   Train Accuracy : 88.566
#
#
# Test accuracy: 86 %
# Epoch:  55   Loss:  222.80677822232246   Train Accuracy : 88.834
#
#
# Test accuracy: 87 %
# Epoch:  56   Loss:  216.41405165195465   Train Accuracy : 89.172
#
#
# Test accuracy: 87 %
# Epoch:  57   Loss:  219.36826564371586   Train Accuracy : 89.092
#
#
# Test accuracy: 86 %
# Epoch:  58   Loss:  211.83730643987656   Train Accuracy : 89.464
#
#
# Test accuracy: 87 %
# Epoch:  59   Loss:  212.087831646204   Train Accuracy : 89.662
#
#
# Test accuracy: 87 %
# Epoch:  60   Loss:  193.8449023514986   Train Accuracy : 90.564
#
#
# Test accuracy: 87 %
# Epoch:  61   Loss:  185.74184368550777   Train Accuracy : 91.298
#
#
# Test accuracy: 88 %
# Epoch:  62   Loss:  178.82216122746468   Train Accuracy : 91.786
#
#
# Test accuracy: 88 %
# Epoch:  63   Loss:  174.59718661010265   Train Accuracy : 92.006
#
#
# Test accuracy: 88 %
# Epoch:  64   Loss:  173.40172216296196   Train Accuracy : 92.05
#
#
# Test accuracy: 87 %
# Epoch:  65   Loss:  173.59989662468433   Train Accuracy : 92.002
#
#
# Test accuracy: 88 %
# Epoch:  66   Loss:  168.24819099903107   Train Accuracy : 92.462
#
#
# Test accuracy: 88 %
# Epoch:  67   Loss:  167.5665517449379   Train Accuracy : 92.544
#
#
# Test accuracy: 87 %
# Epoch:  68   Loss:  168.46538519859314   Train Accuracy : 92.272
#
#
# Test accuracy: 87 %
# Epoch:  69   Loss:  166.24489034712315   Train Accuracy : 92.536
#
#
# Test accuracy: 88 %
# Epoch:  70   Loss:  163.3354031443596   Train Accuracy : 92.61
#
#
# Test accuracy: 88 %
# Epoch:  71   Loss:  161.65034347772598   Train Accuracy : 92.71
#
#
# Test accuracy: 88 %
# Epoch:  72   Loss:  159.83545644581318   Train Accuracy : 92.87
#
#
# Test accuracy: 88 %
# Epoch:  73   Loss:  158.15440467000008   Train Accuracy : 92.97
#
#
# Test accuracy: 88 %
# Epoch:  74   Loss:  160.2288495004177   Train Accuracy : 92.87
#
#
# Test accuracy: 88 %
# Epoch:  75   Loss:  155.42131392657757   Train Accuracy : 93.104
#
#
# Test accuracy: 88 %
# Epoch:  76   Loss:  155.13082896173   Train Accuracy : 93.086
#
#
# Test accuracy: 88 %
# Epoch:  77   Loss:  154.19649557769299   Train Accuracy : 93.204
#
#
# Test accuracy: 88 %
# Epoch:  78   Loss:  156.3577854782343   Train Accuracy : 93.098
#
#
# Test accuracy: 87 %
# Epoch:  79   Loss:  153.0645066201687   Train Accuracy : 93.208
#
#
# Test accuracy: 87 %
# Epoch:  80   Loss:  138.0695555061102   Train Accuracy : 94.248
#
#
# Test accuracy: 88 %
# Epoch:  81   Loss:  131.16972689330578   Train Accuracy : 94.77
#
#
# Test accuracy: 88 %
# Epoch:  82   Loss:  126.61224772036076   Train Accuracy : 94.998
#
#
# Test accuracy: 88 %
# Epoch:  83   Loss:  120.72247694432735   Train Accuracy : 95.38
#
#
# Test accuracy: 88 %
# Epoch:  84   Loss:  121.73848970234394   Train Accuracy : 95.368
#
#
# Test accuracy: 88 %
# Epoch:  85   Loss:  119.59256437420845   Train Accuracy : 95.358
#
#
# Test accuracy: 89 %
# Epoch:  86   Loss:  119.27050119638443   Train Accuracy : 95.376
#
#
# Test accuracy: 89 %
# Epoch:  87   Loss:  117.99450247734785   Train Accuracy : 95.648
#
#
# Test accuracy: 88 %
# Epoch:  88   Loss:  115.43717274069786   Train Accuracy : 95.648
#
#
# Test accuracy: 89 %
# Epoch:  89   Loss:  115.29293809086084   Train Accuracy : 95.71
#
#
# Test accuracy: 88 %
# Epoch:  90   Loss:  112.78307646512985   Train Accuracy : 95.916
#
#
# Test accuracy: 89 %
# Epoch:  91   Loss:  111.88460817933083   Train Accuracy : 95.87
#
#
# Test accuracy: 89 %
# Epoch:  92   Loss:  112.59504886716604   Train Accuracy : 95.874
#
#
# Test accuracy: 89 %
# Epoch:  93   Loss:  112.76145132631063   Train Accuracy : 95.828
#
#
# Test accuracy: 88 %
# Epoch:  94   Loss:  113.59861013293266   Train Accuracy : 95.726
#
#
# Test accuracy: 88 %
# Epoch:  95   Loss:  111.47762662172318   Train Accuracy : 95.93
#
#
# Test accuracy: 89 %
# Epoch:  96   Loss:  111.8002212420106   Train Accuracy : 95.848
#
#
# Test accuracy: 88 %
# Epoch:  97   Loss:  111.27855809032917   Train Accuracy : 95.85
#
#
# Test accuracy: 88 %
# Epoch:  98   Loss:  111.3264265730977   Train Accuracy : 95.852
#
#
# Test accuracy: 88 %
# Epoch:  99   Loss:  109.1719848588109   Train Accuracy : 95.896
#
#
# Test accuracy: 88 %
# Epoch:  100   Loss:  100.95660462230444   Train Accuracy : 96.506
#
#
# Test accuracy: 89 %
# Epoch:  101   Loss:  91.10674589127302   Train Accuracy : 97.168
#
#
# Test accuracy: 89 %
# Epoch:  102   Loss:  93.41191644966602   Train Accuracy : 97.094
#
#
# Test accuracy: 89 %
# Epoch:  103   Loss:  91.23859052360058   Train Accuracy : 97.2
#
#
# Test accuracy: 88 %
# Epoch:  104   Loss:  87.84703792631626   Train Accuracy : 97.442
#
#
# Test accuracy: 89 %
# Epoch:  105   Loss:  89.11533285677433   Train Accuracy : 97.318
#
#
# Test accuracy: 89 %
# Epoch:  106   Loss:  87.40399990975857   Train Accuracy : 97.266
#
#
# Test accuracy: 89 %
# Epoch:  107   Loss:  84.94944409281015   Train Accuracy : 97.52
#
#
# Test accuracy: 89 %
# Epoch:  108   Loss:  86.24530054628849   Train Accuracy : 97.466
#
#
# Test accuracy: 89 %
# Epoch:  109   Loss:  85.13824102282524   Train Accuracy : 97.578
#
#
# Test accuracy: 89 %
# Epoch:  110   Loss:  81.96046235412359   Train Accuracy : 97.692
#
#
# Test accuracy: 89 %
# Epoch:  111   Loss:  83.20088635385036   Train Accuracy : 97.578
#
#
# Test accuracy: 89 %
# Epoch:  112   Loss:  81.40477311611176   Train Accuracy : 97.75
#
#
# Test accuracy: 89 %
# Epoch:  113   Loss:  83.52821914851665   Train Accuracy : 97.626
#
#
# Test accuracy: 89 %
# Epoch:  114   Loss:  82.45623679459095   Train Accuracy : 97.638
#
#
# Test accuracy: 89 %
# Epoch:  115   Loss:  81.06541825830936   Train Accuracy : 97.758
#
#
# Test accuracy: 89 %
# Epoch:  116   Loss:  81.60987959802151   Train Accuracy : 97.74
#
#
# Test accuracy: 89 %
# Epoch:  117   Loss:  82.37037514895201   Train Accuracy : 97.564
#
#
# Test accuracy: 89 %
# Epoch:  118   Loss:  81.32163129746914   Train Accuracy : 97.676
#
#
# Test accuracy: 89 %
# Epoch:  119   Loss:  81.13686656206846   Train Accuracy : 97.718
#
#
# Test accuracy: 89 %
# Epoch:  120   Loss:  76.92094374448061   Train Accuracy : 97.994
#
#
# Test accuracy: 89 %
# Epoch:  121   Loss:  73.52246244251728   Train Accuracy : 98.22
#
#
# Test accuracy: 89 %
# Epoch:  122   Loss:  72.60218366235495   Train Accuracy : 98.192
#
#
# Test accuracy: 90 %
# Epoch:  123   Loss:  70.90480465441942   Train Accuracy : 98.366
#
#
# Test accuracy: 89 %
# Epoch:  124   Loss:  70.99539089202881   Train Accuracy : 98.37
#
#
# Test accuracy: 90 %
# Epoch:  125   Loss:  69.56692610681057   Train Accuracy : 98.45
#
#
# Test accuracy: 90 %
# Epoch:  126   Loss:  70.49411734193563   Train Accuracy : 98.344
#
#
# Test accuracy: 89 %
# Epoch:  127   Loss:  67.51890175789595   Train Accuracy : 98.518
#
#
# Test accuracy: 89 %
# Epoch:  128   Loss:  68.2037170752883   Train Accuracy : 98.51
#
#
# Test accuracy: 89 %
# Epoch:  129   Loss:  68.83814074844122   Train Accuracy : 98.502
#
#
# Test accuracy: 89 %
# Epoch:  130   Loss:  67.54101056605577   Train Accuracy : 98.52
#
#
# Test accuracy: 89 %
# Epoch:  131   Loss:  68.94188179820776   Train Accuracy : 98.414
#
#
# Test accuracy: 89 %
# Epoch:  132   Loss:  65.71298895776272   Train Accuracy : 98.652
#
#
# Test accuracy: 90 %
# Epoch:  133   Loss:  66.78944347053766   Train Accuracy : 98.662
#
#
# Test accuracy: 89 %
# Epoch:  134   Loss:  66.4526501595974   Train Accuracy : 98.598
#
#
# Test accuracy: 89 %
# Epoch:  135   Loss:  64.90844562649727   Train Accuracy : 98.624
#
#
# Test accuracy: 89 %
# Epoch:  136   Loss:  64.7542843259871   Train Accuracy : 98.668
#
#
# Test accuracy: 90 %
# Epoch:  137   Loss:  66.12322516739368   Train Accuracy : 98.652
#
#
# Test accuracy: 89 %
# Epoch:  138   Loss:  64.47229698300362   Train Accuracy : 98.724
#
#
# Test accuracy: 89 %
# Epoch:  139   Loss:  63.97934461385012   Train Accuracy : 98.69
#
#
# Test accuracy: 89 %
# Epoch:  140   Loss:  63.88732820749283   Train Accuracy : 98.798
#
#
# Test accuracy: 90 %
# Epoch:  141   Loss:  61.80761503428221   Train Accuracy : 98.814
#
#
# Test accuracy: 90 %
# Epoch:  142   Loss:  61.53795129060745   Train Accuracy : 98.858
#
#
# Test accuracy: 89 %
# Epoch:  143   Loss:  59.9634055159986   Train Accuracy : 98.946
#
#
# Test accuracy: 89 %
# Epoch:  144   Loss:  59.82726227864623   Train Accuracy : 98.994
#
#
# Test accuracy: 90 %
# Epoch:  145   Loss:  60.37218115106225   Train Accuracy : 98.964
#
#
# Test accuracy: 89 %
# Epoch:  146   Loss:  59.406328082084656   Train Accuracy : 98.948
#
#
# Test accuracy: 90 %
# Epoch:  147   Loss:  58.097200989723206   Train Accuracy : 99.022
#
#
# Test accuracy: 89 %
# Epoch:  148   Loss:  58.49016332626343   Train Accuracy : 99.09
#
#
# Test accuracy: 90 %
# Epoch:  149   Loss:  58.41143224015832   Train Accuracy : 99.054
#
#
# Test accuracy: 89 %
# Epoch:  150   Loss:  58.47849936783314   Train Accuracy : 99.034
#
#
# Test accuracy: 90 %
# Epoch:  151   Loss:  59.472685519605875   Train Accuracy : 98.99
#
#
# Test accuracy: 90 %
# Epoch:  152   Loss:  56.97311281785369   Train Accuracy : 99.15
#
#
# Test accuracy: 90 %

# %%
test_acc = [14,25,36, 41,44,48,51,55,58,62,63,66,66,68, 69,71,73,75,73,75,78,78,79,79,79,80,81,81,81,82,82,82,82,83,82,
            84,84,83,84,85,85,85,86,85,85,86,86,86,86,86,86,86,86,87,86,87,87,86,87,87,87,88, 88,88,87, 88,88, 87, 87,88, 
            88, 88, 88, 88, 88, 88, 88,88,87, 87, 88, 88, 88, 88,88,88,89,89,88,89,88,89,89,89,88,88,89,88,88,88,88,89,89,
            89,88,89,89,89,89,89,89,89,89,89,89,89,89 ,89,89,89,89,89,89,90,89,90,90,89,89,89,89,89,89,90,89,89,89,90,
            89,89,89,90,90,89,89,90,89,90,89,90,89,90,90,90]

# %%
# import pickle

# with open("accuracy_randT.pkl", "wb") as output_file:
#         pickle.dump(test_acc, output_file)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot([i for i in range(len(test_acc))], test_acc, label = "RandomT Network")
plt.xlabel("Epoch")
plt.ylabel("% Accuracy")
plt.title("Test Accuracy of Flexible Network with Random Threshold")
plt.legend()
plt.show()
