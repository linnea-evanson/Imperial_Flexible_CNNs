# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# ================================================= Flexible Layer ================================================================================

    
class FlexiLayer(nn.Module): # class FlexiLayer(nn.Conv2d):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1,
                 padding=0):
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.stride = stride
        self.padding = padding
        super(FlexiLayer, self).__init__()
        
        self.t_1 = nn.Conv2d(self.in_channels, self.out_channels, self.kernel_size, self.stride, self.padding)
        self.t_2 = nn.MaxPool2d(self.kernel_size, self.stride, self.padding) # get max result with the same kernel size
        self.m = nn.Sigmoid()
        
        self.threshold1 = Variable(torch.randn((1, self.out_channels, 30, 30)))
        
        self.thresh_mean = []
        
    def forward(self, t):
        
        #self.threshold1.expand(t.size(0), self.out_channels, 30, 30)
        
        
        #cond = torch.sub(self.t_2(t), self.threshold1.cuda())
        #t_2_2 = self.m(cond*50)*self.t_2(t) # 
        #t_1_1 = self.m(cond*(-50))*self.t_1(t) # 
        #t = torch.add(t_2_2, t_1_1)
        
        return self.t_1(t)

    # ================================================= VGG-16 Network ================================================================================
class VGG16(nn.Module):
    def __init__(self):
        super(VGG16,self).__init__()

        self.block1 = nn.Sequential(
                      nn.Conv2d(in_channels = 3,out_channels = 64,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(64),
                      nn.ReLU(),
                      FlexiLayer(in_channels = 64,out_channels = 64,kernel_size = 3, padding =0),
                      nn.BatchNorm2d(64),
                      nn.ReLU(),
                      #nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.3))

        self.block2 = nn.Sequential(
                      nn.Conv2d(in_channels = 64,out_channels = 128,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(128),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 128,out_channels = 128,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(128),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.4))

        self.block3 = nn.Sequential(
                      nn.Conv2d(in_channels = 128,out_channels = 256,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(256),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(256),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(256),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.4))

        self.block4 = nn.Sequential(
                      nn.Conv2d(in_channels = 256,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2) ,
                      nn.Dropout2d(0.4))

        self.block5 = nn.Sequential(
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.5) )

        self.fc =     nn.Sequential(
                      nn.Linear(512,100),
                      nn.Dropout(0.5),
                      nn.BatchNorm1d(100),
                      nn.ReLU(),
                      nn.Dropout(0.5),
                      nn.Linear(100,10), )




    def forward(self,x):
        out = self.block1(x)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = out.view(out.size(0),-1)
        out = self.fc(out)

        return out

# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np


# =================================================== Prepare the dataset ===============================================================================

mean_cifar10 = [0.485, 0.456, 0.406]  # Mean and Std value hase been taken from a github implmentation online.
std_cifar10 = [0.229, 0.224, 0.225]
batch_size = 100
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

trainset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=True, download= True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') # 10 Classes of the cifar-10

# ========================================== Visualising the dataset ==========================================================================
std= torch.FloatTensor(std_cifar10)
mean = torch.FloatTensor(mean_cifar10)
mean = mean[:,None,None]
std = std[:,None,None]
def imshow(img):
    print(img.size())
    img = img*std + mean     # unnormalize
    
    npimg = img.numpy()
    
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
# truck  bird truck  deer

# %%
# ======================== Function to get the test accuracy ===============================================================================
def test():
    correct = 0
    total = 0
    model.train(False)
    with torch.no_grad():
        for i,(images,labels)in enumerate(testloader):
            if torch.cuda.is_available():
                images = images.cuda()
                labels = labels.cuda()
            outputs = model(Variable(images))
            labels = Variable(labels)
            _,predicted = outputs.max(1)
            total += labels.size(0)
            correct += (predicted.eq(labels)).sum().item()
        print('Test accuracy: %d %%' % (
        100 * correct / total))
    return 100*(correct/total)

#======================================================= Training =========================================================================

def train(num_epochs, model_number):
    start_epoch = 0
    total_step = len(trainloader)
    train_loss = []  # Store the train_loss per epoch
    test_accuracy = [] # Store the test_accuracy per epoch
    for epoch in range(start_epoch,num_epochs+1):
        model.train(True)
        epoch_loss  = 0
        i_count = 0
        acc_total = 0
        for i,(images,labels) in enumerate(trainloader):
            if torch.cuda.is_available():
                images = images.cuda()
                labels = labels.cuda()
            labels = Variable(labels)
            optimizer.zero_grad()
            outputs = model(Variable(images))
            loss = criterion(outputs,labels)
            epoch_loss += loss.item()
            loss.backward()
            optimizer.step()
            _,predicted = outputs.max(1)
            denom = labels.size(0)
            correct = predicted.eq(labels).sum().item()
            acc = 100*(correct/denom)
            acc_total += acc
            i_count = i_count + 1

        schedule.step()
        train_loss.append(epoch_loss)
        print("Epoch: ",epoch," ","Loss: ",epoch_loss," ","Train Accuracy :",acc_total/i_count) # Print train accuracy per epoch
        test_acc = test()      # Print the test accuracy per epoch
        test_accuracy.append(test_acc)
        print('\n')


        if(epoch == num_epochs - 1 ):       # Save the model on the last epoch
            state = {
                'model': model.state_dict(),
                'acc' : test_acc,
                'optim':optimizer.state_dict(),
                'epoch' : epoch
            }
            path = './models/100networks/VGG16-BASE-nnmodule_' + 'model' + model_number + '_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
            torch.save(state,path)
            
            train_error_final_epoch = 100 - acc_total/i_count
            
            return path, train_error_final_epoch

# %%
#Need to call the train function 100 times, each with different starting conditions and number of epochs

train_errors = [] #we don't actually care about this
all_models = []

#Get 101 different lengths of epochs, between 10 and 300:
num_models = 5

import random
num_epochs = random.choices([i for i in range(0,300)], k = num_models)  #k should be 101 but would take 12.5 days, if 3hrs each.


for i in range(num_models): #need to reinintialise a model for each iteration, to ensure weights etc are reset.
    
    #============== Model initialisation, Loss function and Optimizer ===========
    model = VGG16()
    if torch.cuda.is_available():
        model.cuda()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum = 0.9,weight_decay = 0.006)
    schedule = torch.optim.lr_scheduler.StepLR(optimizer,step_size=20,gamma = 0.7)
   
    
    path, train_error_i = train(num_epochs[i], i)
    train_errors.append(train_error_i)
    all_models.append(path)
    
    #Train with Newton optimiser to find nearest critical point (do in a seperate script)
# Out:
# Epoch:  0   Loss:  1074.3043876886368   Train Accuracy : 17.628
# Test accuracy: 16 %
#
#
# Epoch:  1   Loss:  948.488648891449   Train Accuracy : 26.258
# Test accuracy: 25 %
#
#
# Epoch:  2   Loss:  882.9758962392807   Train Accuracy : 32.914
# Test accuracy: 32 %
#
#
# Epoch:  3   Loss:  837.7467423677444   Train Accuracy : 36.824
# Test accuracy: 40 %
#
#
# Epoch:  4   Loss:  802.8506246805191   Train Accuracy : 40.284
# Test accuracy: 44 %
#
#
# Epoch:  5   Loss:  763.7773313522339   Train Accuracy : 44.036
# Test accuracy: 47 %
#
#
# Epoch:  6   Loss:  728.0223460197449   Train Accuracy : 47.598
# Test accuracy: 54 %
#
#
# Epoch:  7   Loss:  692.117476940155   Train Accuracy : 51.632
# Test accuracy: 57 %
#
#
# Epoch:  8   Loss:  652.3734384775162   Train Accuracy : 55.2
# Test accuracy: 61 %
#
#
# Epoch:  9   Loss:  620.6758863329887   Train Accuracy : 58.164
# Test accuracy: 62 %
#
#
# Epoch:  10   Loss:  589.9884436130524   Train Accuracy : 60.612
# Test accuracy: 66 %
#
#
# Epoch:  11   Loss:  563.6973606944084   Train Accuracy : 62.78
# Test accuracy: 68 %
#
#
# Epoch:  12   Loss:  539.2846433520317   Train Accuracy : 64.85
# Test accuracy: 68 %
#
#
# Epoch:  13   Loss:  518.623129606247   Train Accuracy : 66.424
# Test accuracy: 71 %
#
#
# Epoch:  14   Loss:  500.09969490766525   Train Accuracy : 67.948
# Test accuracy: 74 %
#
#
# Epoch:  15   Loss:  478.98719930648804   Train Accuracy : 69.87
# Test accuracy: 75 %
#
#
# Epoch:  16   Loss:  458.090380191803   Train Accuracy : 71.506
# Test accuracy: 76 %
#
#
# Epoch:  17   Loss:  440.4428388476372   Train Accuracy : 72.926
# Test accuracy: 78 %
#
#
# Epoch:  18   Loss:  425.7602383494377   Train Accuracy : 74.202
# Test accuracy: 79 %
#
#
# Epoch:  19   Loss:  411.8894813656807   Train Accuracy : 75.196
# Test accuracy: 79 %
#
#
# Epoch:  20   Loss:  384.4663699269295   Train Accuracy : 77.326
# Test accuracy: 80 %
#
#
# Epoch:  21   Loss:  370.81940546631813   Train Accuracy : 78.606
# Test accuracy: 82 %
#
#
# Epoch:  22   Loss:  358.34761026501656   Train Accuracy : 79.452
# Test accuracy: 82 %
#
#
# Epoch:  23   Loss:  352.03185695409775   Train Accuracy : 79.766
# Test accuracy: 82 %
#
#
# Epoch:  24   Loss:  342.51904994249344   Train Accuracy : 80.888
# Test accuracy: 82 %
#
#
# Epoch:  25   Loss:  334.1445301771164   Train Accuracy : 81.026
# Test accuracy: 83 %
#
#
# Epoch:  26   Loss:  326.598326086998   Train Accuracy : 81.688
# Test accuracy: 84 %
#
#
# Epoch:  27   Loss:  321.17279118299484   Train Accuracy : 82.09
# Test accuracy: 84 %
#
#
# Epoch:  28   Loss:  313.9760681092739   Train Accuracy : 82.59
# Test accuracy: 84 %
#
#
# Epoch:  29   Loss:  307.6813586950302   Train Accuracy : 82.94
# Test accuracy: 85 %
#
#
# Epoch:  30   Loss:  299.7059026658535   Train Accuracy : 83.554
# Test accuracy: 85 %
#
#
# Epoch:  31   Loss:  294.01019954681396   Train Accuracy : 84.016
# Test accuracy: 84 %
#
#
# Epoch:  32   Loss:  286.28301680088043   Train Accuracy : 84.412
# Test accuracy: 85 %
#
#
# Epoch:  33   Loss:  282.8666571378708   Train Accuracy : 84.77
# Test accuracy: 86 %
#
#
# Epoch:  34   Loss:  275.6639983355999   Train Accuracy : 85.134
# Test accuracy: 85 %
#
#
# Epoch:  35   Loss:  271.13627046346664   Train Accuracy : 85.428
# Test accuracy: 86 %
#
#
# Epoch:  36   Loss:  266.69414830207825   Train Accuracy : 85.836
# Test accuracy: 86 %
#
#
# Epoch:  37   Loss:  261.0601623058319   Train Accuracy : 86.224
# Test accuracy: 87 %
#
#
# Epoch:  38   Loss:  257.92127284407616   Train Accuracy : 86.434
# Test accuracy: 86 %
#
#
# Epoch:  39   Loss:  253.11487048864365   Train Accuracy : 86.868
# Test accuracy: 87 %
#
#
# Epoch:  40   Loss:  232.62221321463585   Train Accuracy : 88.204
# Test accuracy: 87 %
#
#
# Epoch:  41   Loss:  222.4419025182724   Train Accuracy : 88.766
# Test accuracy: 87 %
#
#
# Epoch:  42   Loss:  218.56485763192177   Train Accuracy : 89.216
# Test accuracy: 87 %
#
#
# Epoch:  43   Loss:  215.40593910217285   Train Accuracy : 89.294
# Test accuracy: 88 %
#
#
# Epoch:  44   Loss:  212.11473682522774   Train Accuracy : 89.502
# Test accuracy: 88 %
#
#
# Epoch:  45   Loss:  206.11542716622353   Train Accuracy : 89.84
# Test accuracy: 88 %
#
#
# Epoch:  46   Loss:  204.2016884535551   Train Accuracy : 90.108
# Test accuracy: 88 %
#
#
# Epoch:  47   Loss:  201.36579275131226   Train Accuracy : 90.2
# Test accuracy: 88 %
#
#
# Epoch:  48   Loss:  200.09361638128757   Train Accuracy : 90.268
# Test accuracy: 88 %
#
#
# Epoch:  49   Loss:  196.4598531126976   Train Accuracy : 90.588
# Test accuracy: 87 %
#
#
# Epoch:  50   Loss:  192.8188599795103   Train Accuracy : 90.676
# Test accuracy: 88 %
#
#
# Epoch:  51   Loss:  195.34228821098804   Train Accuracy : 90.612
# Test accuracy: 88 %
#
#
# Epoch:  52   Loss:  189.74917793273926   Train Accuracy : 90.762
# Test accuracy: 88 %
#
#
# Epoch:  53   Loss:  186.97510714828968   Train Accuracy : 91.014
# Test accuracy: 88 %
#
#
# Epoch:  54   Loss:  188.08990381658077   Train Accuracy : 91.02
# Test accuracy: 89 %
#
#
# Epoch:  55   Loss:  184.4217006266117   Train Accuracy : 91.306
# Test accuracy: 88 %
#
#
# Epoch:  56   Loss:  179.19955691695213   Train Accuracy : 91.67
# Test accuracy: 88 %
#
#
# Epoch:  57   Loss:  179.81177738308907   Train Accuracy : 91.54
# Test accuracy: 88 %
#
#
# Epoch:  58   Loss:  179.47127586603165   Train Accuracy : 91.612
# Test accuracy: 88 %
#
#
# Epoch:  59   Loss:  174.9872102290392   Train Accuracy : 91.836
# Test accuracy: 89 %
#
#
# Epoch:  60   Loss:  156.18413938581944   Train Accuracy : 93.016
# Test accuracy: 89 %
#
#
# Epoch:  61   Loss:  146.74268370866776   Train Accuracy : 93.642
# Test accuracy: 89 %
#
#
# Epoch:  62   Loss:  145.8366718441248   Train Accuracy : 93.726
# Test accuracy: 89 %
#
#
# Epoch:  63   Loss:  146.0624217838049   Train Accuracy : 93.86
# Test accuracy: 89 %
#
#
# Epoch:  64   Loss:  142.7713920623064   Train Accuracy : 93.85
# Test accuracy: 89 %
#
#
# Epoch:  65   Loss:  137.29219779372215   Train Accuracy : 94.222
# Test accuracy: 89 %
#
#
# Epoch:  66   Loss:  135.22353895753622   Train Accuracy : 94.386
# Test accuracy: 89 %
#
#
# Epoch:  67   Loss:  133.54180082678795   Train Accuracy : 94.508
# Test accuracy: 89 %
#
#
# Epoch:  68   Loss:  134.41082902252674   Train Accuracy : 94.462
# Test accuracy: 89 %
#
#
# Epoch:  69   Loss:  133.85622809827328   Train Accuracy : 94.484
# Test accuracy: 89 %
#
#
# Epoch:  70   Loss:  132.89650017023087   Train Accuracy : 94.56
# Test accuracy: 90 %
#
#
# Epoch:  71   Loss:  129.76525583863258   Train Accuracy : 94.716
# Test accuracy: 90 %
#
#
# Epoch:  72   Loss:  128.66754285991192   Train Accuracy : 94.898
# Test accuracy: 89 %
#
#
# Epoch:  73   Loss:  128.78065446019173   Train Accuracy : 94.862
# Test accuracy: 89 %
#
#
# Epoch:  74   Loss:  131.19811706244946   Train Accuracy : 94.6
# Test accuracy: 89 %
#
#
# Epoch:  75   Loss:  128.83820412307978   Train Accuracy : 94.69
# Test accuracy: 89 %
#
#
# Epoch:  76   Loss:  125.81973583996296   Train Accuracy : 94.968
# Test accuracy: 89 %
#
#
# Epoch:  77   Loss:  129.62111739814281   Train Accuracy : 94.806
# Test accuracy: 90 %
#
#
# Epoch:  78   Loss:  125.32683979719877   Train Accuracy : 95.05
# Test accuracy: 89 %
#
#
# Epoch:  79   Loss:  124.74872408807278   Train Accuracy : 94.97
# Test accuracy: 89 %
#
#
# Epoch:  80   Loss:  112.81263926625252   Train Accuracy : 95.738
# Test accuracy: 89 %
#
#
# Epoch:  81   Loss:  107.13912834227085   Train Accuracy : 96.186
# Test accuracy: 90 %
#
#
# Epoch:  82   Loss:  101.60750621557236   Train Accuracy : 96.492
# Test accuracy: 90 %
#
#
# Epoch:  83   Loss:  99.52332673966885   Train Accuracy : 96.702
# Test accuracy: 90 %
#
#
# Epoch:  84   Loss:  100.80727724730968   Train Accuracy : 96.582
# Test accuracy: 90 %
#
#
# Epoch:  85   Loss:  98.26709175854921   Train Accuracy : 96.694
# Test accuracy: 90 %
#
#
# Epoch:  86   Loss:  96.34617367386818   Train Accuracy : 96.836
# Test accuracy: 90 %
#
#
# Epoch:  87   Loss:  93.20716033875942   Train Accuracy : 97.034
# Test accuracy: 90 %
#
#
# Epoch:  88   Loss:  94.51547800004482   Train Accuracy : 96.93
# Test accuracy: 90 %
#
#
# Epoch:  89   Loss:  93.98210030794144   Train Accuracy : 96.996
# Test accuracy: 90 %
#
#
# Epoch:  90   Loss:  95.0527139827609   Train Accuracy : 96.87
# Test accuracy: 90 %
#
#
# Epoch:  91   Loss:  92.87217155843973   Train Accuracy : 97.014
# Test accuracy: 90 %
#
#
# Epoch:  92   Loss:  92.55635584145784   Train Accuracy : 97.05
# Test accuracy: 90 %
#
#
# Epoch:  93   Loss:  91.6027012616396   Train Accuracy : 97.062
# Test accuracy: 90 %
#
#
# Epoch:  94   Loss:  92.31592675298452   Train Accuracy : 97.082
# Test accuracy: 90 %
#
#
# Epoch:  95   Loss:  90.52357672154903   Train Accuracy : 97.186
# Test accuracy: 90 %
#
#
# Epoch:  96   Loss:  90.24396359920502   Train Accuracy : 97.102
# Test accuracy: 90 %
#
#
# Epoch:  97   Loss:  89.56314600259066   Train Accuracy : 97.198
# Test accuracy: 90 %
#
#
# Epoch:  98   Loss:  94.05209585279226   Train Accuracy : 96.916
# Test accuracy: 90 %
#
#
# Epoch:  99   Loss:  93.33323726058006   Train Accuracy : 96.944
# Test accuracy: 90 %
#
#
# Epoch:  100   Loss:  84.70597185194492   Train Accuracy : 97.412
# Test accuracy: 90 %
#
#
# Epoch:  101   Loss:  79.86475413292646   Train Accuracy : 97.832
# Test accuracy: 90 %
#
#
# Epoch:  102   Loss:  77.33547289669514   Train Accuracy : 97.988
# Test accuracy: 90 %
#
#
# Epoch:  103   Loss:  76.62316175550222   Train Accuracy : 97.946
# Test accuracy: 90 %
#
#
# Epoch:  104   Loss:  74.41597004979849   Train Accuracy : 98.176
# Test accuracy: 90 %
#
#
# Epoch:  105   Loss:  72.43267984688282   Train Accuracy : 98.26
# Test accuracy: 91 %
#
#
# Epoch:  106   Loss:  74.40158709138632   Train Accuracy : 98.038
# Test accuracy: 90 %
#
#
# Epoch:  107   Loss:  73.43792725354433   Train Accuracy : 98.174
# Test accuracy: 90 %
#
#
# Epoch:  108   Loss:  73.89710809290409   Train Accuracy : 98.126
# Test accuracy: 90 %
#
#
# Epoch:  109   Loss:  72.00185659527779   Train Accuracy : 98.254
# Test accuracy: 90 %
#
#
# Epoch:  110   Loss:  68.98610355705023   Train Accuracy : 98.426
# Test accuracy: 90 %
#
#
# Epoch:  111   Loss:  70.2601780667901   Train Accuracy : 98.306
# Test accuracy: 90 %
#
#
# Epoch:  112   Loss:  70.26195798069239   Train Accuracy : 98.358
# Test accuracy: 90 %
#
#
# Epoch:  113   Loss:  70.00890340656042   Train Accuracy : 98.384
# Test accuracy: 90 %
#
#
# Epoch:  114   Loss:  72.25423546135426   Train Accuracy : 98.166
# Test accuracy: 90 %
#
#
# Epoch:  115   Loss:  71.30836315453053   Train Accuracy : 98.278
# Test accuracy: 90 %
#
#
# Epoch:  116   Loss:  70.2282060533762   Train Accuracy : 98.338
# Test accuracy: 90 %
#
#
# Epoch:  117   Loss:  70.63624249771237   Train Accuracy : 98.32
# Test accuracy: 91 %
#
#
# Epoch:  118   Loss:  70.37888581305742   Train Accuracy : 98.29
# Test accuracy: 90 %
#
#
# Epoch:  119   Loss:  70.3851635530591   Train Accuracy : 98.246
# Test accuracy: 91 %
#
#
# Epoch:  120   Loss:  65.78069028258324   Train Accuracy : 98.572
# Test accuracy: 91 %
#
#
# Epoch:  121   Loss:  65.42605821788311   Train Accuracy : 98.582
# Test accuracy: 90 %
#
#
# Epoch:  122   Loss:  63.729289285838604   Train Accuracy : 98.714
# Test accuracy: 90 %
#
#
# Epoch:  123   Loss:  62.87475959956646   Train Accuracy : 98.764
# Test accuracy: 91 %
#
#
# Epoch:  124   Loss:  62.003522381186485   Train Accuracy : 98.856
# Test accuracy: 91 %
#
#
# Epoch:  125   Loss:  61.78671512007713   Train Accuracy : 98.806
# Test accuracy: 91 %
#
#
# Epoch:  126   Loss:  60.919398069381714   Train Accuracy : 98.95
# Test accuracy: 91 %
#
#
# Epoch:  127   Loss:  60.42525977268815   Train Accuracy : 98.894
# Test accuracy: 91 %
#
#
# Epoch:  128   Loss:  60.47672176361084   Train Accuracy : 98.854
# Test accuracy: 91 %
#
#
# Epoch:  129   Loss:  60.06562537699938   Train Accuracy : 98.872
# Test accuracy: 91 %
#
#
# Epoch:  130   Loss:  58.9174364246428   Train Accuracy : 99.018
# Test accuracy: 90 %
#
#
# Epoch:  131   Loss:  60.12675075978041   Train Accuracy : 98.974
# Test accuracy: 90 %
#
#
# Epoch:  132   Loss:  60.1661416888237   Train Accuracy : 98.912
# Test accuracy: 90 %
#
#
# Epoch:  133   Loss:  60.21808425337076   Train Accuracy : 98.906
# Test accuracy: 90 %
#
#
# Epoch:  134   Loss:  59.63310498744249   Train Accuracy : 98.924
# Test accuracy: 91 %
#
#
# Epoch:  135   Loss:  59.013151463121176   Train Accuracy : 98.974
# Test accuracy: 91 %
#
#
# Epoch:  136   Loss:  59.47835186123848   Train Accuracy : 98.91
# Test accuracy: 91 %
#
#
# Epoch:  137   Loss:  58.79824134707451   Train Accuracy : 98.936
# Test accuracy: 91 %
#
#
# Epoch:  138   Loss:  58.233279313892126   Train Accuracy : 99.002
# Test accuracy: 91 %
#
#
# Epoch:  139   Loss:  58.38596606627107   Train Accuracy : 99.018
# Test accuracy: 91 %
#
#
# Epoch:  140   Loss:  57.34736004471779   Train Accuracy : 99.002
# Test accuracy: 91 %
#
#
# Epoch:  141   Loss:  55.74395588412881   Train Accuracy : 99.15
# Test accuracy: 91 %
#
#
# Epoch:  142   Loss:  55.44073347002268   Train Accuracy : 99.14
# Test accuracy: 91 %
#
#
# Epoch:  143   Loss:  54.5976228415966   Train Accuracy : 99.228
# Test accuracy: 91 %
#
#
# Epoch:  144   Loss:  55.81652209535241   Train Accuracy : 99.052
# Test accuracy: 91 %
#
#
# Epoch:  145   Loss:  54.477232214063406   Train Accuracy : 99.234
# Test accuracy: 91 %
#
#
# Epoch:  146   Loss:  55.05150440707803   Train Accuracy : 99.18
# Test accuracy: 91 %
#
#
# Epoch:  147   Loss:  54.92009621113539   Train Accuracy : 99.168
# Test accuracy: 91 %
#
#
# Epoch:  148   Loss:  54.46585929766297   Train Accuracy : 99.186
# Test accuracy: 91 %
#
#
# Epoch:  149   Loss:  53.90838638320565   Train Accuracy : 99.19
# Test accuracy: 91 %
#
#
# Epoch:  150   Loss:  52.85276072472334   Train Accuracy : 99.254
# Test accuracy: 91 %
#
#
# Epoch:  151   Loss:  53.70526820793748   Train Accuracy : 99.26
# Test accuracy: 91 %
#
#
# Epoch:  152   Loss:  53.51655710488558   Train Accuracy : 99.246
# Test accuracy: 91 %
#
#
# Epoch:  153   Loss:  54.17520256340504   Train Accuracy : 99.226
# Test accuracy: 91 %
#
#
# Epoch:  154   Loss:  53.20321287214756   Train Accuracy : 99.282
# Test accuracy: 91 %
#
#
# Epoch:  155   Loss:  54.028370663523674   Train Accuracy : 99.218
# Test accuracy: 91 %
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-6dd221dd2f47> in <module>
#      22
#      23
# ---> 24     path, train_error_i = train(num_epochs[i], i)
#      25     train_errors.append(train_error_i)
#      26     all_models.append(path)
#
# <ipython-input-3-07ed5c40dca9> in train(num_epochs, model_number)
#      63                 'epoch' : epoch
#      64             }
# ---> 65             path = './models/100networks/VGG16-BASE-nnmodule_' + 'model' + model_number + '_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
#      66             torch.save(state,path)
#      67
#
# TypeError: can only concatenate str (not "int") to str

# %%
#For alpha - epsilon plot we want test accuracy at the final epoch after Newton method.
import pickle

with open('cifar_base_100model_paths.pkl', 'wb') as f:
    pickle.dump(all_models, f)
