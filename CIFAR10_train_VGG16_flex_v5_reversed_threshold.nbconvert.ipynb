# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# ================================================= Flexible Layer ================================================================================

    
class FlexiLayer(nn.Module): # class FlexiLayer(nn.Conv2d):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1,
                 padding=0):
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.kernel_size = kernel_size
        self.stride = stride
        self.padding = padding
        super(FlexiLayer, self).__init__()
        
        self.t_1 = nn.Conv2d(self.in_channels, self.out_channels, self.kernel_size, self.stride, self.padding)
        self.t_2 = nn.MaxPool2d(self.kernel_size, self.stride, self.padding) # get max result with the same kernel size
        self.m = nn.Sigmoid()
        
        self.threshold1 = Variable(torch.randn((1, self.out_channels, 30, 30)))
        
        self.thresh_mean = []
        
    def forward(self, t):
        
        self.threshold1.expand(t.size(0), self.out_channels, 30, 30)
        
        
        cond = torch.sub(self.threshold1.cuda(), self.t_2(t))  #this is the part that is reversed!!
        t_2_2 = self.m(cond*50)*self.t_2(t) # 
        t_1_1 = self.m(cond*(-50))*self.t_1(t) # 
        t = torch.add(t_2_2, t_1_1)
        
        return t

    # ================================================= VGG-16 Network ================================================================================
class VGG16(nn.Module):
    def __init__(self):
        super(VGG16,self).__init__()

        self.block1 = nn.Sequential(
                      nn.Conv2d(in_channels = 3,out_channels = 64,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(64),
                      nn.ReLU(),
                      FlexiLayer(in_channels = 64,out_channels = 64,kernel_size = 3, padding =0),
                      nn.BatchNorm2d(64),
                      nn.ReLU(),
                      #nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.3))

        self.block2 = nn.Sequential(
                      nn.Conv2d(in_channels = 64,out_channels = 128,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(128),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 128,out_channels = 128,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(128),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.4))

        self.block3 = nn.Sequential(
                      nn.Conv2d(in_channels = 128,out_channels = 256,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(256),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(256),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 256,out_channels = 256,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(256),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.4))

        self.block4 = nn.Sequential(
                      nn.Conv2d(in_channels = 256,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2) ,
                      nn.Dropout2d(0.4))

        self.block5 = nn.Sequential(
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3,padding = 1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.Conv2d(in_channels = 512,out_channels = 512,kernel_size = 3, padding =1),
                      nn.BatchNorm2d(512),
                      nn.ReLU(),
                      nn.MaxPool2d(kernel_size=2, stride=2),
                      nn.Dropout2d(0.5) )

        self.fc =     nn.Sequential(
                      nn.Linear(512,100),
                      nn.Dropout(0.5),
                      nn.BatchNorm1d(100),
                      nn.ReLU(),
                      nn.Dropout(0.5),
                      nn.Linear(100,10), )




    def forward(self,x):
        out = self.block1(x)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = out.view(out.size(0),-1)
        out = self.fc(out)

        return out

# %%
 #===================================================== Import libraries ================================================================================

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn 
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

#from models.VGG16_with_flex_v5 import *


# =================================================== Prepare the dataset ===============================================================================

mean_cifar10 = [0.485, 0.456, 0.406]  # Mean and Std value hase been taken from a github implmentation online.
std_cifar10 = [0.229, 0.224, 0.225]
batch_size = 100
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean_cifar10,std_cifar10),
])

trainset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=True, download= True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='../FlexibleCNNs/data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck') # 10 Classes of the cifar-10

# ========================================== Visualising the dataset ==========================================================================
std= torch.FloatTensor(std_cifar10)
mean = torch.FloatTensor(mean_cifar10)
mean = mean[:,None,None]
std = std[:,None,None]
def imshow(img):
    print(img.size())
    img = img*std + mean     # unnormalize
    
    npimg = img.numpy()
    
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
#  bird   dog  ship  ship

# %%
# =============================================================== Model initialisation, Loss function and Optimizer =====================================
model = VGG16()
if torch.cuda.is_available():
    model.cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum = 0.9,weight_decay = 0.006)
schedule = torch.optim.lr_scheduler.StepLR(optimizer,step_size=20,gamma = 0.7)

total_params = sum(p.numel() for p in model.parameters())
print(f'{total_params:,} total parameters.')
total_trainable_params = sum(
    p.numel() for p in model.parameters() if p.requires_grad)
print(f'{total_trainable_params:,} trainable parameters.')
# Out:
# 14,775,646 total parameters.
# 14,775,646 trainable parameters.

# %%
# ======================== Function to get the test accuracy ===============================================================================
def test():
    correct = 0
    total = 0
    model.train(False)
    with torch.no_grad():
        for i,(images,labels)in enumerate(testloader):
            if torch.cuda.is_available():
                images = images.cuda()
                labels = labels.cuda()
            outputs = model(Variable(images))
            labels = Variable(labels)
            _,predicted = outputs.max(1)
            total += labels.size(0)
            correct += (predicted.eq(labels)).sum().item()
    print('Test accuracy: %d %%' % (
    100 * correct / total))
    return 100*(correct/total)

#======================================================= Training =========================================================================
num_epochs = 152  # Train for 150 epochs
start_epoch = 0

total_step = len(trainloader)
train_loss = []  # Store the train_loss per epoch
test_accuracy = [] # Store the test_accuracy per epoch
for epoch in range(start_epoch,num_epochs+1):
    model.train(True)
    epoch_loss  = 0
    i_count = 0
    acc_total = 0
    for i,(images,labels) in enumerate(trainloader):
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()
        labels = Variable(labels)
        optimizer.zero_grad()
        outputs = model(Variable(images))
        loss = criterion(outputs,labels)
        epoch_loss += loss.item()
        loss.backward()
        optimizer.step()
        _,predicted = outputs.max(1)
        denom = labels.size(0)
        correct = predicted.eq(labels).sum().item()
        acc = 100*(correct/denom)
        acc_total += acc
        i_count = i_count + 1
    
    #if(i%20 == 0):  # Print the loss per 20 iterations
      #print("Epoch: ",epoch," ","Iteration: ",i," loss: ",loss.item()," Train_iter Accuracy: ",acc)
    schedule.step()
    train_loss.append(epoch_loss)
    print("Epoch: ",epoch," ","Loss: ",epoch_loss," ","Train Accuracy :",acc_total/i_count) # Print train accuracy per epoch
    print('\n')
    test_acc = test()      # Print the test accuracy per epoch
    test_accuracy.append(test_acc)

    if(epoch%50 == 0):       # Save the model every 50 epoch
        state = {
            'model': model.state_dict(),
            'acc' : test_acc,
            'optim':optimizer.state_dict(),
            'epoch' : epoch
        }
        path = './models/VGG16-flex-v5-block1-nnmodule_reversedT' + 'model_' + str(int(epoch)) +'_' + str(int(test_acc))+'.pth'
        torch.save(state,path)
# Out:
# Epoch:  0   Loss:  1108.8686670064926   Train Accuracy : 15.436
#
#
# Test accuracy: 12 %
# Epoch:  1   Loss:  988.2185176610947   Train Accuracy : 23.762
#
#
# Test accuracy: 20 %
# Epoch:  2   Loss:  923.654655456543   Train Accuracy : 29.666
#
#
# Test accuracy: 29 %
# Epoch:  3   Loss:  875.379158616066   Train Accuracy : 33.78
#
#
# Test accuracy: 35 %
# Epoch:  4   Loss:  841.8842475414276   Train Accuracy : 36.686
#
#
# Test accuracy: 40 %
# Epoch:  5   Loss:  810.1285775899887   Train Accuracy : 40.09
#
#
# Test accuracy: 44 %
# Epoch:  6   Loss:  778.0085079669952   Train Accuracy : 42.892
#
#
# Test accuracy: 48 %
# Epoch:  7   Loss:  747.074885725975   Train Accuracy : 45.758
#
#
# Test accuracy: 53 %
# Epoch:  8   Loss:  718.3412065505981   Train Accuracy : 49.222
#
#
# Test accuracy: 56 %
# Epoch:  9   Loss:  689.4722768068314   Train Accuracy : 51.854
#
#
# Test accuracy: 59 %
# Epoch:  10   Loss:  656.4560294151306   Train Accuracy : 55.004
#
#
# Test accuracy: 60 %
# Epoch:  11   Loss:  626.487006008625   Train Accuracy : 57.694
#
#
# Test accuracy: 64 %
# Epoch:  12   Loss:  600.658574461937   Train Accuracy : 59.81
#
#
# Test accuracy: 64 %
# Epoch:  13   Loss:  577.5741604566574   Train Accuracy : 61.884
#
#
# Test accuracy: 67 %
# Epoch:  14   Loss:  556.3037036657333   Train Accuracy : 63.65
#
#
# Test accuracy: 68 %
# Epoch:  15   Loss:  531.5659921765327   Train Accuracy : 65.46
#
#
# Test accuracy: 71 %
# Epoch:  16   Loss:  517.8610023856163   Train Accuracy : 66.84
#
#
# Test accuracy: 71 %
# Epoch:  17   Loss:  495.89076495170593   Train Accuracy : 68.716
#
#
# Test accuracy: 73 %
# Epoch:  18   Loss:  478.56552344560623   Train Accuracy : 69.908
#
#
# Test accuracy: 75 %
# Epoch:  19   Loss:  464.9961450099945   Train Accuracy : 71.232
#
#
# Test accuracy: 76 %
# Epoch:  20   Loss:  438.42724907398224   Train Accuracy : 73.392
#
#
# Test accuracy: 77 %
# Epoch:  21   Loss:  419.5748926997185   Train Accuracy : 74.712
#
#
# Test accuracy: 78 %
# Epoch:  22   Loss:  409.1647215485573   Train Accuracy : 75.394
#
#
# Test accuracy: 78 %
# Epoch:  23   Loss:  398.9134292602539   Train Accuracy : 76.256
#
#
# Test accuracy: 79 %
# Epoch:  24   Loss:  390.3042815923691   Train Accuracy : 76.996
#
#
# Test accuracy: 79 %
# Epoch:  25   Loss:  377.95924538373947   Train Accuracy : 77.854
#
#
# Test accuracy: 80 %
# Epoch:  26   Loss:  372.51573637127876   Train Accuracy : 78.312
#
#
# Test accuracy: 80 %
# Epoch:  27   Loss:  365.25032567977905   Train Accuracy : 78.926
#
#
# Test accuracy: 81 %
# Epoch:  28   Loss:  354.6470003724098   Train Accuracy : 79.48
#
#
# Test accuracy: 82 %
# Epoch:  29   Loss:  350.0228123962879   Train Accuracy : 79.832
#
#
# Test accuracy: 82 %
# Epoch:  30   Loss:  340.3444453179836   Train Accuracy : 80.67
#
#
# Test accuracy: 82 %
# Epoch:  31   Loss:  333.3609667420387   Train Accuracy : 81.014
#
#
# Test accuracy: 83 %
# Epoch:  32   Loss:  328.4396654367447   Train Accuracy : 81.544
#
#
# Test accuracy: 82 %
# Epoch:  33   Loss:  318.29198065400124   Train Accuracy : 82.172
#
#
# Test accuracy: 83 %
# Epoch:  34   Loss:  312.2814726829529   Train Accuracy : 82.674
#
#
# Test accuracy: 82 %
# Epoch:  35   Loss:  305.51036870479584   Train Accuracy : 83.042
#
#
# Test accuracy: 83 %
# Epoch:  36   Loss:  300.44869151711464   Train Accuracy : 83.352
#
#
# Test accuracy: 84 %
# Epoch:  37   Loss:  292.9377557337284   Train Accuracy : 84.052
#
#
# Test accuracy: 84 %
# Epoch:  38   Loss:  290.2904908657074   Train Accuracy : 84.21
#
#
# Test accuracy: 84 %
# Epoch:  39   Loss:  285.90725207328796   Train Accuracy : 84.4
#
#
# Test accuracy: 84 %
# Epoch:  40   Loss:  262.2567107975483   Train Accuracy : 86.19
#
#
# Test accuracy: 85 %
# Epoch:  41   Loss:  249.906362503767   Train Accuracy : 86.864
#
#
# Test accuracy: 86 %
# Epoch:  42   Loss:  247.21373146772385   Train Accuracy : 87.06
#
#
# Test accuracy: 86 %
# Epoch:  43   Loss:  245.92968413233757   Train Accuracy : 87.202
#
#
# Test accuracy: 86 %
# Epoch:  44   Loss:  237.7102226614952   Train Accuracy : 87.918
#
#
# Test accuracy: 86 %
# Epoch:  45   Loss:  234.2272089421749   Train Accuracy : 87.938
#
#
# Test accuracy: 86 %
# Epoch:  46   Loss:  231.48666834831238   Train Accuracy : 88.26
#
#
# Test accuracy: 86 %
# Epoch:  47   Loss:  230.36598172783852   Train Accuracy : 88.17
#
#
# Test accuracy: 86 %
# Epoch:  48   Loss:  222.9154204428196   Train Accuracy : 88.568
#
#
# Test accuracy: 86 %
# Epoch:  49   Loss:  221.4431213736534   Train Accuracy : 88.854
#
#
# Test accuracy: 86 %
# Epoch:  50   Loss:  217.08522555232048   Train Accuracy : 89.034
#
#
# Test accuracy: 86 %
# Epoch:  51   Loss:  219.684022128582   Train Accuracy : 89.054
#
#
# Test accuracy: 86 %
# Epoch:  52   Loss:  213.24115198850632   Train Accuracy : 89.356
#
#
# Test accuracy: 87 %
# Epoch:  53   Loss:  211.25811664760113   Train Accuracy : 89.412
#
#
# Test accuracy: 87 %
# Epoch:  54   Loss:  205.51688754558563   Train Accuracy : 89.724
#
#
# Test accuracy: 86 %
# Epoch:  55   Loss:  205.8233968168497   Train Accuracy : 89.758
#
#
# Test accuracy: 87 %
# Epoch:  56   Loss:  202.8457256704569   Train Accuracy : 90.054
#
#
# Test accuracy: 86 %
# Epoch:  57   Loss:  199.20425164699554   Train Accuracy : 90.254
#
#
# Test accuracy: 86 %
# Epoch:  58   Loss:  196.1115878224373   Train Accuracy : 90.404
#
#
# Test accuracy: 86 %
# Epoch:  59   Loss:  197.3988988995552   Train Accuracy : 90.292
#
#
# Test accuracy: 87 %
# Epoch:  60   Loss:  176.54049789905548   Train Accuracy : 91.704
#
#
# Test accuracy: 87 %
# Epoch:  61   Loss:  171.99658100306988   Train Accuracy : 92.044
#
#
# Test accuracy: 88 %
# Epoch:  62   Loss:  160.778260871768   Train Accuracy : 92.804
#
#
# Test accuracy: 88 %
# Epoch:  63   Loss:  162.2841476202011   Train Accuracy : 92.574
#
#
# Test accuracy: 87 %
# Epoch:  64   Loss:  157.82685494422913   Train Accuracy : 93.002
#
#
# Test accuracy: 87 %
# Epoch:  65   Loss:  158.17335060238838   Train Accuracy : 93.084
#
#
# Test accuracy: 88 %
# Epoch:  66   Loss:  152.12723971903324   Train Accuracy : 93.306
#
#
# Test accuracy: 88 %
# Epoch:  67   Loss:  150.4719660282135   Train Accuracy : 93.304
#
#
# Test accuracy: 87 %
# Epoch:  68   Loss:  151.32432660460472   Train Accuracy : 93.396
#
#
# Test accuracy: 88 %
# Epoch:  69   Loss:  151.0456127524376   Train Accuracy : 93.334
#
#
# Test accuracy: 88 %
# Epoch:  70   Loss:  149.17716136574745   Train Accuracy : 93.394
#
#
# Test accuracy: 87 %
# Epoch:  71   Loss:  148.16693337261677   Train Accuracy : 93.342
#
#
# Test accuracy: 88 %
# Epoch:  72   Loss:  143.83040948212147   Train Accuracy : 93.892
#
#
# Test accuracy: 88 %
# Epoch:  73   Loss:  146.58645282685757   Train Accuracy : 93.556
#
#
# Test accuracy: 87 %
# Epoch:  74   Loss:  140.10198460519314   Train Accuracy : 94.166
#
#
# Test accuracy: 88 %
# Epoch:  75   Loss:  142.6573552340269   Train Accuracy : 93.838
#
#
# Test accuracy: 88 %
# Epoch:  76   Loss:  143.44877438992262   Train Accuracy : 93.914
#
#
# Test accuracy: 88 %
# Epoch:  77   Loss:  142.98313395678997   Train Accuracy : 93.944
#
#
# Test accuracy: 88 %
# Epoch:  78   Loss:  139.22006127238274   Train Accuracy : 94.214
#
#
# Test accuracy: 88 %
# Epoch:  79   Loss:  135.83346384763718   Train Accuracy : 94.312
#
#
# Test accuracy: 87 %
# Epoch:  80   Loss:  122.11548749357462   Train Accuracy : 95.202
#
#
# Test accuracy: 88 %
# Epoch:  81   Loss:  116.70613149553537   Train Accuracy : 95.564
#
#
# Test accuracy: 88 %
# Epoch:  82   Loss:  113.00958731025457   Train Accuracy : 95.802
#
#
# Test accuracy: 89 %
# Epoch:  83   Loss:  112.48744988441467   Train Accuracy : 95.754
#
#
# Test accuracy: 88 %
# Epoch:  84   Loss:  110.47061607986689   Train Accuracy : 95.884
#
#
# Test accuracy: 88 %
# Epoch:  85   Loss:  103.93334814161062   Train Accuracy : 96.526
#
#
# Test accuracy: 88 %
# Epoch:  86   Loss:  105.38869588822126   Train Accuracy : 96.256
#
#
# Test accuracy: 88 %
# Epoch:  87   Loss:  104.66443040966988   Train Accuracy : 96.282
#
#
# Test accuracy: 88 %
# Epoch:  88   Loss:  103.26780457049608   Train Accuracy : 96.442
#
#
# Test accuracy: 89 %
# Epoch:  89   Loss:  103.26450222730637   Train Accuracy : 96.312
#
#
# Test accuracy: 88 %
# Epoch:  90   Loss:  101.30355104804039   Train Accuracy : 96.386
#
#
# Test accuracy: 88 %
# Epoch:  91   Loss:  102.38045533746481   Train Accuracy : 96.406
#
#
# Test accuracy: 88 %
# Epoch:  92   Loss:  102.05718214809895   Train Accuracy : 96.44
#
#
# Test accuracy: 88 %
# Epoch:  93   Loss:  102.54281736165285   Train Accuracy : 96.434
#
#
# Test accuracy: 89 %
# Epoch:  94   Loss:  100.85637803375721   Train Accuracy : 96.458
#
#
# Test accuracy: 88 %
# Epoch:  95   Loss:  99.72745135426521   Train Accuracy : 96.568
#
#
# Test accuracy: 88 %
# Epoch:  96   Loss:  100.26612388342619   Train Accuracy : 96.534
#
#
# Test accuracy: 88 %
# Epoch:  97   Loss:  99.48800151795149   Train Accuracy : 96.552
#
#
# Test accuracy: 89 %
# Epoch:  98   Loss:  98.96448425203562   Train Accuracy : 96.59
#
#
# Test accuracy: 89 %
# Epoch:  99   Loss:  98.32585552334785   Train Accuracy : 96.632
#
#
# Test accuracy: 88 %
# Epoch:  100   Loss:  88.63538045436144   Train Accuracy : 97.22
#
#
# Test accuracy: 88 %
# Epoch:  101   Loss:  87.03012052923441   Train Accuracy : 97.48
#
#
# Test accuracy: 89 %
# Epoch:  102   Loss:  83.39159975200891   Train Accuracy : 97.608
#
#
# Test accuracy: 89 %
# Epoch:  103   Loss:  80.84736196696758   Train Accuracy : 97.74
#
#
# Test accuracy: 89 %
# Epoch:  104   Loss:  80.06428354233503   Train Accuracy : 97.71
#
#
# Test accuracy: 89 %
# Epoch:  105   Loss:  78.30784456431866   Train Accuracy : 97.894
#
#
# Test accuracy: 89 %
# Epoch:  106   Loss:  78.76801104098558   Train Accuracy : 97.85
#
#
# Test accuracy: 89 %
# Epoch:  107   Loss:  78.02266907691956   Train Accuracy : 97.89
#
#
# Test accuracy: 89 %
# Epoch:  108   Loss:  76.4933856651187   Train Accuracy : 98.032
#
#
# Test accuracy: 89 %
# Epoch:  109   Loss:  77.58424845337868   Train Accuracy : 97.896
#
#
# Test accuracy: 89 %
# Epoch:  110   Loss:  75.35885576158762   Train Accuracy : 98.092
#
#
# Test accuracy: 88 %
# Epoch:  111   Loss:  75.35427284985781   Train Accuracy : 98.052
#
#
# Test accuracy: 89 %
# Epoch:  112   Loss:  75.73769755661488   Train Accuracy : 97.95
#
#
# Test accuracy: 89 %
# Epoch:  113   Loss:  75.69215147197247   Train Accuracy : 97.966
#
#
# Test accuracy: 89 %
# Epoch:  114   Loss:  73.47199978679419   Train Accuracy : 98.034
#
#
# Test accuracy: 89 %
# Epoch:  115   Loss:  74.20495345443487   Train Accuracy : 98.0
#
#
# Test accuracy: 88 %
# Epoch:  116   Loss:  74.17472191154957   Train Accuracy : 98.012
#
#
# Test accuracy: 89 %
# Epoch:  117   Loss:  73.95451208949089   Train Accuracy : 98.09
#
#
# Test accuracy: 89 %
# Epoch:  118   Loss:  73.02808612585068   Train Accuracy : 98.154
#
#
# Test accuracy: 89 %
# Epoch:  119   Loss:  76.02684545516968   Train Accuracy : 97.948
#
#
# Test accuracy: 89 %
# Epoch:  120   Loss:  71.19411581009626   Train Accuracy : 98.22
#
#
# Test accuracy: 89 %
# Epoch:  121   Loss:  67.82380983233452   Train Accuracy : 98.428
#
#
# Test accuracy: 89 %
# Epoch:  122   Loss:  67.60353780537844   Train Accuracy : 98.406
#
#
# Test accuracy: 89 %
# Epoch:  123   Loss:  66.69798833876848   Train Accuracy : 98.47
#
#
# Test accuracy: 89 %
# Epoch:  124   Loss:  63.53386303782463   Train Accuracy : 98.712
#
#
# Test accuracy: 89 %
# Epoch:  125   Loss:  65.00207675993443   Train Accuracy : 98.53
#
#
# Test accuracy: 89 %
# Epoch:  126   Loss:  64.24795451760292   Train Accuracy : 98.602
#
#
# Test accuracy: 89 %
# Epoch:  127   Loss:  62.843192741274834   Train Accuracy : 98.764
#
#
# Test accuracy: 89 %
# Epoch:  128   Loss:  64.14116785302758   Train Accuracy : 98.62
#
#
# Test accuracy: 89 %
# Epoch:  129   Loss:  63.80816923081875   Train Accuracy : 98.662
#
#
# Test accuracy: 89 %
# Epoch:  130   Loss:  62.08279414474964   Train Accuracy : 98.77
#
#
# Test accuracy: 89 %
# Epoch:  131   Loss:  62.45589582622051   Train Accuracy : 98.732
#
#
# Test accuracy: 89 %
# Epoch:  132   Loss:  61.90042012184858   Train Accuracy : 98.73
#
#
# Test accuracy: 89 %
# Epoch:  133   Loss:  62.4366104491055   Train Accuracy : 98.722
#
#
# Test accuracy: 89 %
# Epoch:  134   Loss:  61.691683404147625   Train Accuracy : 98.776
#
#
# Test accuracy: 89 %
# Epoch:  135   Loss:  60.924709033221006   Train Accuracy : 98.854
#
#
# Test accuracy: 89 %
# Epoch:  136   Loss:  59.89896089211106   Train Accuracy : 98.864
#
#
# Test accuracy: 89 %
# Epoch:  137   Loss:  61.010110050439835   Train Accuracy : 98.814
#
#
# Test accuracy: 89 %
# Epoch:  138   Loss:  59.07575926557183   Train Accuracy : 98.956
#
#
# Test accuracy: 89 %
# Epoch:  139   Loss:  58.94307841360569   Train Accuracy : 98.892
#
#
# Test accuracy: 89 %
# Epoch:  140   Loss:  58.27673239260912   Train Accuracy : 98.952
#
#
# Test accuracy: 89 %
# Epoch:  141   Loss:  58.09439869970083   Train Accuracy : 98.908
#
#
# Test accuracy: 89 %
# Epoch:  142   Loss:  57.28148493915796   Train Accuracy : 98.952
#
#
# Test accuracy: 89 %
# Epoch:  143   Loss:  55.9092461168766   Train Accuracy : 99.084
#
#
# Test accuracy: 89 %
# Epoch:  144   Loss:  56.33164083212614   Train Accuracy : 99.08
#
#
# Test accuracy: 89 %
# Epoch:  145   Loss:  55.579775139689445   Train Accuracy : 99.072
#
#
# Test accuracy: 89 %
# Epoch:  146   Loss:  55.93144229054451   Train Accuracy : 99.114
#
#
# Test accuracy: 89 %
# Epoch:  147   Loss:  54.61363764107227   Train Accuracy : 99.102
#
#
# Test accuracy: 89 %
# Epoch:  148   Loss:  55.00522193312645   Train Accuracy : 99.136
#
#
# Test accuracy: 89 %
# Epoch:  149   Loss:  54.78562078624964   Train Accuracy : 99.188
#
#
# Test accuracy: 90 %
# Epoch:  150   Loss:  55.53141218051314   Train Accuracy : 99.118
#
#
# Test accuracy: 89 %
# Epoch:  151   Loss:  53.866451762616634   Train Accuracy : 99.158
#
#
# Test accuracy: 89 %
# Epoch:  152   Loss:  54.746250972151756   Train Accuracy : 99.09
#
#
# Test accuracy: 89 %

# %%
import pickle

with open("VGG16flex_revT_test_acc.pkl", "wb") as output_file:
    pickle.dump(test_accuracy, output_file)

# %%
#======================================= Testing ===================================================================================================
test_acc = test() # Test error
print(test_acc)

# Per class accuracy
class_correct = list(0. for i in range(10)) # Individual class error
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
          images = images.cuda()
          labels = labels.cuda()
        images = Variable(images)
        labels = Variable(labels)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Test accuracy: 89 %
# 89.92999999999999
# Accuracy of plane : 93 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 78 %
# Accuracy of   cat : 81 %
# Accuracy of  deer : 85 %
# Accuracy of   dog : 87 %
# Accuracy of  frog : 96 %
# Accuracy of horse : 93 %
# Accuracy of  ship : 95 %
# Accuracy of truck : 100 %

# %%
'''  
The image lies between [0,1] but since I have trained the whole network on normalized input, Therefore
the min_val = -2.117 and max_val = 2.64 and not {0,1}
'''

# FGSM attack code
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, -2.117, 2.64)
    # Return the perturbed image
    return perturbed_image

def test( model, device, test_loader, epsilon ):

    # Accuracy counter
    correct = 0
    adv_examples = []

    # Loop over all examples in test set
    for data, target in test_loader:

        # Send the data and label to the device
        data, target = data.to(device), target.to(device)

        # Set requires_grad attribute of tensor. Important for Attack
        data.requires_grad = True

        # Forward pass the data through the model
        output = model(data)
        init_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability

        # If the initial prediction is wrong, dont bother attacking, just move on
        #if init_pred.item() != target.item():
        #    continue

        # Calculate the loss
        loss = F.nll_loss(output, target)

        # Zero all existing gradients
        model.zero_grad()

        # Calculate gradients of model in backward pass
        loss.backward()

        # Collect datagrad
        data_grad = data.grad.data

        # Call FGSM Attack
        perturbed_data = fgsm_attack(data, epsilon, data_grad)

        # Re-classify the perturbed image
        output = model(perturbed_data)

        # Check for success
        final_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
        for i in range(0,len(final_pred)-1):
            if final_pred[i].sub(target[i]) == 0:
                correct += 1
                # Special case for saving 0 epsilon examples
                if (epsilon == 0) and (len(adv_examples) < 5):
                    adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                    adv_examples.append( (init_pred[i], final_pred[i], adv_ex) )
            else:
                # Save some adv examples for visualization later
                if len(adv_examples) < 5:
                    adv_ex = perturbed_data.squeeze().detach().cpu().numpy()
                    adv_examples.append( (init_pred[i], final_pred[i], adv_ex) )

    # Calculate final accuracy for this epsilon
    final_acc = correct/float(len(test_loader))
    print("Epsilon: {}\tTest Accuracy = {} / {} = {}".format(epsilon, correct, len(test_loader), final_acc))

    # Return the accuracy and an adversarial example
    return final_acc, adv_examples

# %%
#evaluate model
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = model(images.cuda())
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels.cuda()).sum().item()

print('Accuracy on the test dataset is: %f %%' % (
    100 * correct / total))
# Out:
# Accuracy on the test dataset is: 89.930000 %

# %%
accuracies = []
examples = []
epsilons = [0, .05, .1, .15, .2, .25, .3, .35, .4, .45, .5, .55, .6, .65, .7, .75, .8, .85, .9, .95, 1]

# Define what device we are using
print("CUDA Available: ",torch.cuda.is_available())
use_cuda=True
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")

# Run test for each epsilon
for eps in epsilons:
    acc, ex = test(model, device, testloader, eps)
    accuracies.append(acc)
    examples.append(ex)
# Out:
# CUDA Available:  True
# Epsilon: 0	Test Accuracy = 8907 / 100 = 89.07
# Epsilon: 0.05	Test Accuracy = 5552 / 100 = 55.52
# Epsilon: 0.1	Test Accuracy = 5030 / 100 = 50.3
# Epsilon: 0.15	Test Accuracy = 4784 / 100 = 47.84
# Epsilon: 0.2	Test Accuracy = 4558 / 100 = 45.58
# Epsilon: 0.25	Test Accuracy = 4268 / 100 = 42.68
# Epsilon: 0.3	Test Accuracy = 3989 / 100 = 39.89
# Epsilon: 0.35	Test Accuracy = 3592 / 100 = 35.92
# Epsilon: 0.4	Test Accuracy = 3211 / 100 = 32.11
# Epsilon: 0.45	Test Accuracy = 2840 / 100 = 28.4
# Epsilon: 0.5	Test Accuracy = 2505 / 100 = 25.05
# Epsilon: 0.55	Test Accuracy = 2215 / 100 = 22.15
# Epsilon: 0.6	Test Accuracy = 1954 / 100 = 19.54
# Epsilon: 0.65	Test Accuracy = 1765 / 100 = 17.65
# Epsilon: 0.7	Test Accuracy = 1629 / 100 = 16.29
# Epsilon: 0.75	Test Accuracy = 1510 / 100 = 15.1
# Epsilon: 0.8	Test Accuracy = 1441 / 100 = 14.41
# Epsilon: 0.85	Test Accuracy = 1361 / 100 = 13.61
# Epsilon: 0.9	Test Accuracy = 1305 / 100 = 13.05
# Epsilon: 0.95	Test Accuracy = 1258 / 100 = 12.58
# Epsilon: 1	Test Accuracy = 1234 / 100 = 12.34

# %%
with open("VGG16flex_revT_fgsm_acc.pkl", "wb") as output_file:
    pickle.dump(accuracies, output_file)

# %%
plt.figure(figsize=(5,5))
plt.plot(epsilons, torch.tensor(accuracies).div(100), "*-")
plt.yticks(np.arange(0, 1.1, step=0.1))
plt.xticks(np.arange(0, .35, step=0.05))
plt.title("Accuracy vs Epsilon")
plt.xlabel("Epsilon")
plt.ylabel("Accuracy")
plt.show()
